# %%
import pandas as pd

# %%
import numpy as np
import shapely

# %%
bos_addr = pd.read_csv('/Users/DavidStier/Documents/Python and Data Science/DSI Class/Final Project/Model Building/BostonAddressTest.csv')
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
bos_addr.shape
# Out:
# (99073, 19)

# %%
bos_addr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99073 entries, 0 to 99072
# Data columns (total 19 columns):
# PID                99073 non-null int64
# ST_NUM             99073 non-null object
# STNum_nospace      88580 non-null object
# STNum_noLetters    99073 non-null float64
# ST_NAME            99073 non-null object
# ST_NAME_SUF        98995 non-null object
# ZIPCODE            99073 non-null int64
# PTYPE              99073 non-null int64
# LU                 99073 non-null object
# OWN_OCC            99073 non-null object
# AV_LAND            99073 non-null int64
# AV_BLDG            99073 non-null int64
# LAND_SF            99053 non-null float64
# YR_BUILT           98452 non-null float64
# YR_REMOD           77372 non-null float64
# GROSS_AREA         98620 non-null float64
# LIVING_AREA        98620 non-null float64
# LATITUDE           99073 non-null float64
# LONGITUDE          99073 non-null float64
# dtypes: float64(8), int64(5), object(6)
# ...

# %%
bos_addr.head()
# Out:
#           PID  ST_NUM STNum_nospace  STNum_noLetters    ST_NAME ST_NAME_SUF  \
# 0  2101865020    9B              9B              0.0  MONASTERY          RD
# 1  1805555000    9B              9B              0.0    RAWSTON          RD
# 2   802587010  9A -9C           9A               0.0   FAIRLAND          ST
# 3  2101865010    9A              9A              0.0  MONASTERY          RD
# 4  1805557000    9A              9A              0.0    RAWSTON          RD
#
#    ZIPCODE  PTYPE  LU OWN_OCC  AV_LAND  AV_BLDG  LAND_SF  YR_BUILT  YR_REMOD  \
# 0     2135    101  R1       Y   198800   215000   5421.0    1965.0       0.0
# 1     2131    106  RL       N    19900        0   1100.0       0.0       NaN
# 2     2119    995  CM       N        0        0   4911.0    2002.0       NaN
# 3     2135    104  R2       Y   221600   345800   5347.0    1955.0    2002.0
# 4     2131    106  RL       N    19900        0   1100.0       0.0       NaN
#
# ...

# %%
bos_addr['STNum_noLetters'].unique()
# Out:
# array([   0. ,  999. ,  998. , ...,  459. ,  438. ,  152.5])

# %%
bos_addr['block_set'] = bos_addr['STNum_noLetters'].apply(lambda x: x // 100 if x !='has_text' else 0)

# %%
bos_addr.tail(5)
# Out:
#              PID ST_NUM STNum_nospace  STNum_noLetters ST_NAME ST_NAME_SUF  \
# 99068  603765006      1             1              1.0  LAUTEN          PL
# 99069  604500000      1             1              1.0    DEAN          WY
# 99070  100382000      1             1              1.0   SWIFT          TE
# 99071  100706000      1             1              1.0   MOORE          ST
# 99072  102236000      1             1              1.0  ORIENT          AV
#
#        ZIPCODE  PTYPE  LU OWN_OCC  AV_LAND  AV_BLDG  LAND_SF  YR_BUILT  \
# 99068     2127    101  R1       N   117500   242200    948.0    1890.0
# 99069     2127    101  R1       Y   246100   382300   3400.0    1860.0
# 99070     2128    101  R1       N   144500   187900   4436.0    1900.0
# 99071     2128    101  R1       Y   116000   173700   3000.0    1910.0
# 99072     2128    105  R3       N   140500   316600   3320.0    1912.0
#
#        YR_REMOD  GROSS_AREA  LIVING_AREA   LATITUDE  LONGITUDE  block_set
# ...

# %%
bos_addr['block_set'].unique()
# Out:
# array([   0.,    9.,    8.,    7.,    6.,    5.,   53.,   52.,   51.,
#          50.,    4.,   49.,   48.,   47.,   46.,   45.,   44.,   43.,
#          42.,   41.,   40.,   39.,    3.,   38.,   37.,   36.,   35.,
#          34.,   33.,   32.,   31.,   30.,    2.,   29.,   28.,   27.,
#          26.,   25.,   24.,   23.,   22.,   21.,   20.,   19.,    1.,
#          18.,   17.,   16.,   15.,   14.,   13.,   12.,   11.,   10.,
#         427.,  426.,  425.,  424.,  423.,  411.,  399.,  387.,  383.,
#         335.,  275.,  211.,  207.,  126.])

# %%
bos_street_group = bos_addr.groupby(['ST_NAME','block_set'])

# %%
bos_street_group.median()
# Out:
#                                  PID  STNum_noLetters  ZIPCODE  PTYPE  \
# ST_NAME      block_set
# A            0.0        6.012295e+08             17.0   2127.0  390.0
#              1.0        6.027425e+08            170.0   2210.0  440.0
#              2.0        6.011651e+08            244.0   2127.0  390.0
#              3.0        6.027340e+08            323.5   2127.0  345.0
# ABBOT        0.0        1.401931e+09             22.0   2124.0  105.0
# ABBOTSFORD   0.0        1.203003e+09             17.0   2121.0  104.0
# ABBY         0.0        2.200633e+09             14.0   2135.0  250.5
# ABERDEEN     0.0        2.100149e+09             14.0   2215.0  904.0
# ACACIA       0.0        2.009567e+09             15.0   2132.0  101.0
# ACADEMY HILL 0.0        2.204937e+09             32.0   2135.0  104.0
#              1.0        2.204930e+09            112.0   2135.0  101.0
# ACADIA       0.0        6.037260e+08             11.0   2127.0  132.0
# ...

# %%
bos_st_count = bos_street_group.count()

# %%
bos_st_count.head()
# Out:
#                    PID  ST_NUM  STNum_nospace  STNum_noLetters  ST_NAME_SUF  \
# ST_NAME block_set
# A       0.0         26      26             18               26           26
#         1.0          6       6              6                6            6
#         2.0          3       3              3                3            3
#         3.0          4       4              4                4            4
# ABBOT   0.0         27      27             27               27           27
#
#                    ZIPCODE  PTYPE  LU  OWN_OCC  AV_LAND  AV_BLDG  LAND_SF  \
# ST_NAME block_set
# A       0.0             26     26  26       26       26       26       26
#         1.0              6      6   6        6        6        6        6
#         2.0              3      3   3        3        3        3        3
#         3.0              4      4   4        4        4        4        4
# ABBOT   0.0             27     27  27       27       27       27       27
#
# ...
